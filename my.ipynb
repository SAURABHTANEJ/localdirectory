# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
print('hi')
# Out:
# hi

# %%
# %pip install numpy
# Out:
# ...
#   Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl (12.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\GitDemo\\.venv\\Lib\\site-packages\\numpy\\dtypes.py'
# Check the permissions.
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.5 MB 5.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/12.5 MB 3.9 MB/s eta 0:00:03
#    ------- -------------------------------- 2.4/12.5 MB 3.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.4/12.5 MB 3.7 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.5 MB 3.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.0/12.5 MB 3.7 MB/s eta 0:00:03
# ...

# %%
print('Saurabh')
# Out:
# Saurabh
